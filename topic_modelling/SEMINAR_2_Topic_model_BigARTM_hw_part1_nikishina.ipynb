# %%
import artm
# %matplotlib inline
import glob
import os, re
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
from nltk.corpus import stopwords
import numpy as np
from pymorphy2 import MorphAnalyzer
import gensim
morph = MorphAnalyzer()
from nltk.tokenize import word_tokenize
# Out:
# c:\program files\python35\lib\site-packages\gensim\utils.py:1167: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# c:\program files\python35\lib\site-packages\scipy\sparse\sparsetools.py:20: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками**.
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор)
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases);
#
# 3) сохраните тексты .vw формате;
#
# 4) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова, сохраните словарь и посмотрите на него, вдруг что-то плохое сразу будет заметно);
#
# 5) постройте несколько ARTM моделей (переберите количество тем, поменяйте значения tau у регуляризаторов), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 6) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы
#
# 7) в другой ячейки нарисуйте график обучения этой модели
#
# 8) в третьей ячейки опишите какие параметры (количество тем, регуляризаторы, их tau) вы использовали и как обучали (например, после скольки проходов добавили регуляризатор разрежнивания тем (Phi), добавляли ли разреженность документам (Theta) и когда, как повышали значения, сколько итерации модель продожала улучшаться (снижалась перплексия, росли другие метрики);
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 6, 7 и 8. (3, 1, 4 баллов соответственно). Чтобы заработать остальные 2 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %%
def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def clean(words):
    clean = [morph.parse(word)[0].normal_form for word in words if word.isalnum()]
    return clean

# %% [markdown]
# ### 1) Возьмем те же данные и нормализуем (дополнительно убрав стоп-слова и оставив только isalnum()

# %%
habr_texts = [clean(word_tokenize(remove_tags(text.lower()))) for text in open('habr_texts.txt', "r", encoding="utf-8")]

# %%
def preprocess(text_words):
    return [i for i in text_words if i!="lt" and i!="gt" and i not in stopwords.words('english') and i not in stopwords.words('russian')]

# %%
habr_texts = [preprocess(text) for text in habr_texts]

# %% [markdown]
# ### 2) Добавим n-grams

# %%
# вернемся сюда через какое-то время
ph = gensim.models.Phrases(habr_texts, scoring='npmi', threshold=0.5, 
                           common_terms=set(stopwords.words('russian'))) # можно указать слова, которые не будут учитываться
p = gensim.models.phrases.Phraser(ph)
ngrammed_habr_texts = p[habr_texts]

# %%
p[habr_texts[1]]
# Out:
# ['введение',
#  'и',
#  'выбор',
#  'решение',
#  'рано_или_поздно',
#  'наступать',
#  'такой',
#  'момент',
#  'в',
#  'жизнь',
#  'любой',
#  'сообщество',
#  'форум',
#  'когда',
#  'для',
#  'привлечение_и_удержание',
#  'человек',
#  'возникать',
#  'острый_необходимость',
#  'использование',
#  'новое',
#  'инструментарий',
#  'и',
#  'такой',
#  'весьма',
#  'эффективный',
#  'инструмент',
#  'являться',
#  'то',
#  'что',
#  'крыться_за_модный',
#  'ныне',
#  'слово_геймификация',
#  'то',
#  'есть',
#  'использование',
#  'характерный',
#  'для',
#  'игра',
#  'приём',
#  'и',
#  'подход_в_неигровой',
#  'процесс',
#  'по',
#  'привлечение_и_вовлечение',
#  'участник_сообщество',
#  'на',
#  'форум',
#  'в',
#  'создание',
#  'активный',
#  'и',
#  'мощный',
#  'информационный',
#  'поль',
#  'вокруг',
#  'наш',
#  'продукт',
#  'использовать',
#  'в',
#  'наш',
#  'компания_форумный',
#  'движок_xenforo',
#  'в',
#  'настоящее_время',
#  'являться',
#  'наиболее_популярный',
#  'и',
#  'быстро_развивающийся',
#  'этот',
#  'движок',
#  'иметь',
#  'встроить',
#  'система',
#  'трофей_основать',
#  'на',
#  'собственный',
#  'весьма_ограниченный',
#  'система',
#  'критерий',
#  'сам',
#  'система',
#  'создание_трофей',
#  'также',
#  'иметь',
#  'ограниченный',
#  'функционал',
#  'например',
#  'нет',
#  'возможность',
#  'создавать',
#  'трофей_с_графический',
#  'бейджема_нет_возможность',
#  'создавать',
#  'скрытый_трофей',
#  'и',
#  'для',
#  'пример',
#  'привести',
#  'скриншот_дефолтной',
#  'система',
#  'трофей_xenforo',
#  'для',
#  'трофей_addicted',
#  'присваиваться',
#  'в',
#  'случай',
#  'достижение',
#  '1000',
#  'пост',
#  'определение',
#  'критерий',
#  'для',
#  'это',
#  'трофей_выглядеть',
#  'так',
#  'таб_award',
#  'this',
#  'trophy_if_действительно',
#  'вполне_возможно',
#  'создать',
#  'и',
#  'использовать',
#  'геймификация_на_основа',
#  'встроить',
#  'инструментарий',
#  'и',
#  'критерий',
#  'но',
#  'в',
#  'конечный_счёт',
#  'это',
#  'выглядеть',
#  'недостаточно_привлекательно',
#  'и',
#  'современно_критерий',
#  'для',
#  'получение_трофей',
#  'также',
#  'недостаточно',
#  'движок_xenforo',
#  'хороший',
#  'тем',
#  'что',
#  'он',
#  'иметь',
#  'весьма',
#  'серьёзный',
#  'и',
#  'активный_сообщество',
#  'иметься',
#  'и',
#  'русскоязычный',
#  'группа',
#  'который',
#  'постоянно',
#  'работать',
#  'над',
#  'он',
#  'улучшение',
#  'создать',
#  'огромный',
#  'база',
#  'всевозможный',
#  'плагин',
#  'стиль',
#  'шаблон',
#  'и',
#  'они',
#  'бывать',
#  'как',
#  'коммерческий',
#  'так',
#  'и',
#  'бесплатный',
#  'существовать',
#  'даже',
#  'отдельный',
#  'компания',
#  'заниматься_разработка',
#  'и',
#  'продажа',
#  'решение',
#  'для',
#  'xenforo',
#  'например_brivium',
#  'такой',
#  'образ',
#  'потратить',
#  'некоторый_время',
#  'на',
#  'поиск_подходящий',
#  'решение',
#  'и',
#  'запрос',
#  'сообщество',
#  'быть',
#  'определить',
#  'хороший',
#  'на',
#  'сегодняшний_день',
#  'решение',
#  'для',
#  'реализация',
#  'продвинуть',
#  'система',
#  'трофей_и_достижение',
#  'на',
#  'платформа_xenforo',
#  'связка',
#  'плагин_master',
#  'badge_и_cta',
#  'criteria_быть_опробовать',
#  'и',
#  'другой',
#  'популярный',
#  'решение',
#  'например_brivium',
#  'extra_trophies',
#  'awarded_но_они_функциональность',
#  'быть',
#  'оценить_как_недостаточный',
#  'но',
#  'вернуться',
#  'к',
#  'связка_master',
#  'badge_и_cta',
#  'criteria_один_плагин',
#  'представлять',
#  'себя',
#  'платный_35',
#  'мощный',
#  'решение',
#  'для',
#  'управление',
#  'система',
#  'достижение_и_трофей',
#  'а',
#  'два',
#  'плагин',
#  'бесплатный_увеличитель',
#  'количество',
#  'возможный',
#  'критерий',
#  'для',
#  'получение_трофей',
#  'оба',
#  'плагин',
#  'обновляться_нечасто',
#  'но',
#  'в',
#  'год',
#  'обновление',
#  'выходить',
#  'с',
#  'разработчик',
#  'легко',
#  'и',
#  'просто',
#  'связаться',
#  'либо',
#  'в',
#  'обсуждение',
#  'плагин',
#  'на',
#  'он',
#  'страница',
#  'либо',
#  'в',
#  'приватный',
#  'плагин_master',
#  'badge_разобраться',
#  'подробный',
#  'с',
#  'настройка',
#  'плагин_master',
#  'badge_один_таб',
#  'выглядеть',
#  'так',
#  'здесь',
#  'интересный',
#  'опция',
#  'display',
#  'user_featured',
#  'badges_in_member',
#  'card',
#  'и',
#  'связать_с_она_featured',
#  'badges_в_поле',
#  'ниже',
#  'можно',
#  'задать',
#  'сколько',
#  'трофей_юзер',
#  'мочь',
#  'отражать',
#  'на',
#  'свой_memeber',
#  'card',
#  'в',
#  'зависимость',
#  'от',
#  'свой',
#  'текущий',
#  'уровень',
#  'например',
#  'для',
#  'достигнутый',
#  'уровень',
#  'юзер',
#  'мочь',
#  'на',
#  'свой',
#  'member_card',
#  'показать',
#  '5',
#  'заработать_трофей',
#  'выглядеть',
#  'это',
#  'вот',
#  'так',
#  'следующий_таб',
#  'настройка',
#  'выглядеть',
#  'так',
#  'тут',
#  'интерес_представлять',
#  'то',
#  'сколько',
#  'очки',
#  'нужно',
#  'набрать',
#  'до',
#  'достижение',
#  'следующий',
#  'уровень',
#  'points_per',
#  'level',
#  'и',
#  'система',
#  'начисление_очки',
#  'при',
#  'переход',
#  'с',
#  'уровень',
#  'на',
#  'уровень',
#  'выше',
#  'level_up_options',
#  'иметься',
#  'даже',
#  'level_calculator',
#  'для',
#  'вычисление',
#  'необходимый',
#  'количество_очки',
#  'для',
#  'достижение',
#  'тот',
#  'или',
#  'иной',
#  'уровень_и_три_таб',
#  'настройка',
#  'тут',
#  'определяться_месторасположение',
#  'виджет',
#  'прогресс_progress',
#  'to',
#  'next_level',
#  'и',
#  'топ_юзер',
#  'top_level',
#  'в',
#  'сайдбар',
#  'система',
#  'трофей',
#  'для',
#  'начало',
#  'нужно',
#  'сказать',
#  'что',
#  'master_badge',
#  'определять',
#  'два',
#  'важный',
#  'сущность_badge',
#  'и',
#  'trophy_badge',
#  'иметь',
#  'собственный',
#  'свойство',
#  'важный',
#  'из',
#  'который',
#  'badge_mode',
#  'и',
#  'мочь',
#  'включать',
#  'в',
#  'себя',
#  'трофей_trophies',
#  'badge_mode',
#  'мочь',
#  'быть',
#  'visible',
#  'весь',
#  'трофей_входящая',
#  'в',
#  'этот',
#  'badge_видный',
#  'step_by_step',
#  'следующий',
#  'трофей_быть_показать',
#  'только',
#  'после',
#  'тот',
#  'как',
#  'предыдущий',
#  'быть',
#  'получить',
#  'hidden_трофей',
#  'быть',
#  'показать',
#  'только',
#  'тогда',
#  'когда',
#  'быть',
#  'получить',
#  'внутри_badge',
#  'мы',
#  'создавать',
#  'трофей',
#  'хотя',
#  'трофей',
#  'можно',
#  'создавать',
#  'и',
#  'не',
#  'включая_они_в_badge',
#  'в',
#  'окно',
#  'создание_трофей',
#  'иметься_три_таба',
#  'для',
#  'мы',
#  'важный',
#  'один',
#  'два',
#  'на',
#  'первое',
#  'задаваться',
#  'название',
#  'трофей_он_ценность',
#  'trophy_points',
#  'он',
#  'описание',
#  'он',
#  'принадлежность_к_badge',
#  'он',
#  'порядок',
#  'он',
#  'иконка_два_таб',
#  'самый_важный',
#  'здесь',
#  'задаваться',
#  'критерий',
#  'получение_трофей',
#  'и',
#  'благодаря',
#  'уже',
#  'упомянуть',
#  'плагин_cta',
#  'criteria',
#  'количество',
#  'этот',
#  'критерий',
#  'значительно_увеличить',
#  'в',
#  'отличие_от_умолчательный',
#  'система',
#  'трофей_xenforo',
#  'тут',
#  'не',
#  'влезть',
#  'весь_возможный',
#  'критерий',
#  'включить',
#  'только',
#  'один',
#  'достижение',
#  '100',
#  'лайковый_критерий',
#  'для',
#  'трофей_можно_комбинировать',
#  'что',
#  'позволять_создавать',
#  'всевозможный_экзотический',
#  'и',
#  'редкий_трофей',
#  'в',
#  'итог',
#  'формироваться',
#  'определённый',
#  'структура_из_badges',
#  'и',
#  'trophies_интересный',
#  'особенность',
#  'являться',
#  'также',
#  'возможность',
#  'они',
#  'контроль',
#  'выдать_трофей',
#  'определённый',
#  'пользователь',
#  'вне',
#  'очередь',
#  'или',
#  'выдать',
#  'некий',
#  'особенный_трофей',
#  'без',
#  'определённый',
#  'критерий',
#  'конкретный',
#  'пользователь',
#  'за',
#  'особый_заслуга',
#  'можно',
#  'посмотреть',
#  'весь',
#  'пользователь',
#  'обладатель_трофей',
#  'и',
#  'можно',
#  'посмотреть',
#  'иконка_трофей',
#  'такой',
#  'образ',
#  'система',
#  'позволять_создавать',
#  'сложный',
#  'структура',
#  'для',
#  'реализация_геймификация',
#  'на',
#  'форум',
#  'вопрос',
#  'упираться_только_в_фантазия',
#  'для',
#  'создание_трофей',
#  'и',
#  'соответствующий',
#  'графический_оформление',
#  'иконка_трофей',
#  'подразумеваться_что_иконка',
#  'трофей',
#  'должный',
#  'быть',
#  'выдержать_в_единый',
#  'стиль',
#  'и',
#  'выглядеть_привлекательно',
#  'на',
#  'изображение',
#  'выше',
#  'можно',
#  'видеть',
#  'следующий',
#  'тестовый_черновой',
#  'система',
#  'бейдж_poster',
#  'с',
#  'тип',
#  'и',
#  'трофей_основать',
#  'на',
#  'критерий',
#  'количество',
#  'пост',
#  'и',
#  'с',
#  'соответствующий_возрастать',
#  'ценность_бейдж',
#  'favorite_с_тип',
#  'и',
#  'трофей_основать',
#  'на',
#  'критерий',
#  'количество_лайковый',
#  'и',
#  'с',
#  'соответствующий_возрастать',
#  'ценность_бейдж',
#  'cool_pleskian',
#  'с',
#  'тип',
#  'hidden_и_трофей',
#  'за',
#  'привязка_аккаунт',
#  'к',
#  'соцсеть',
#  'за',
#  'достижение_ratio',
#  'отношение',
#  'количество_лайковый',
#  'к',
#  'количество',
#  'пост',
#  'до',
#  'определённый',
#  'в',
#  'критерий',
#  'уровень',
#  'трофей_the_most_useful',
#  'бейдж_years',
#  'of',
#  'service',
#  'с',
#  'тип',
#  'и',
#  'трофей_основать',
#  'на',
#  'критерий',
#  'количество',
#  'день',
#  'с',
#  'момент',
#  'регистрация',
#  'на',
#  'форум',
#  'и',
#  'с',
#  'соответствующий_возрастать',
#  'ценность',
#  'дополнительно',
#  'нужно',
#  'упомянуть',
#  'следующий',
#  'технический_деталь',
#  'трофей',
#  'и',
#  'они',
#  'уровень',
#  'level_points',
#  'подсчитываться',
#  'для',
#  'пользователь',
#  'на',
#  'основа',
#  'срабатывание',
#  'соответствующий_crontask',
#  'который',
#  'при',
#  'желание',
#  'можно',
#  'запустить',
#  'вручную',
#  'система',
#  'с',
#  'сторона',
#  'обычный',
#  'пользователь',
#  'форум',
#  'после',
#  'тот',
#  'как',
#  'система',
#  'трофей',
#  'настроить',
#  'и',
#  'запустить',
#  'с',
#  'сторона',
#  'пользователь',
#  'форум',
#  'она',
#  'видный',
#  'вот',
#  'так',
#  'на',
#  'главное_меню',
#  'форум',
#  'появляться_таб',
#  'badges_с_собственный',
#  'таба_leaderboard',
#  'и',
#  'latest_awarded',
#  'в',
#  'профиль',
#  'каждый',
#  'пользователь',
#  'форум',
#  'так',
#  'же',
#  'появляться',
#  'отдельный_таб',
#  'badges_где_видный',
#  'он',
#  'заслуга',
#  'при',
#  'это',
#  'пользователь',
#  'мочь',
#  'сам',
#  'определить',
#  'какой',
#  'трофей',
#  'он',
#  'мочь',
#  'разместить',
#  'под',
#  'свой_аватара',
#  'в',
#  'форумный_пост',
#  'в',
#  'тред_и_пост',
#  'ваш',
#  'заслуга_быть_видный',
#  'вот',
#  'так',
#  'при',
#  'это',
#  'количество',
#  'позволить',
#  'для',
#  'показ_трофей',
#  'определяться',
#  'уровень',
#  'пользователь',
#  'level_points',
#  'и',
#  'зависеть',
#  'от',
#  'настройка',
#  'плагин_master',
#  'badge_о_чем_быть_сказать',
#  'выше',
#  'факт',
#  'получение',
#  'каждый',
#  'новое',
#  'трофей',
#  'пользователь',
#  'увидеть',
#  'в',
#  'вид',
#  'соответствующий',
#  'alert_в_верхний',
#  'право_угол',
#  'провокационность_и_результат',
#  'технический',
#  'вопрос',
#  'реализация',
#  'безусловно',
#  'важный',
#  'но',
#  'не',
#  'менее_важный',
#  'часть',
#  'система',
#  'она',
#  'наполнение',
#  'создать',
#  'запоминаться_креативный',
#  'и',
#  'яркий',
#  'иконка_трофей',
#  'с',
#  'не',
#  'менее_зажигательный',
#  'описание',
#  'очень',
#  'нетривиальный_задача',
#  'как',
#  'вызвать',
#  'острый_желание',
#  'пользователь',
#  'получить',
#  'тот',
#  'или',
#  'иной',
#  'трофей_путём',
#  'он',
#  'визуализация_и_вербализация',
#  'тема',
#  'отдельный',
#  'исследование',
#  'сказать',
#  'лишь_что_изрядный',
#  'доля_геймерский',
#  'опыт_озорство',
#  'и',
#  'даже',
#  'здоровый_провокационность',
#  'тут',
#  'просто',
#  'необходимый',
#  'при',
#  'это',
#  'важный',
#  'не',
#  'перейти',
#  'некоторый',
#  'грань',
#  'чтобы',
#  'оставаться',
#  'в',
#  'рамка_политкорректность',
#  'религиозный_и_расовый',
#  'терпимость_особенно',
#  'это',
#  'важный',
#  'на',
#  'форум_с_многонациональный',
#  'и',
#  'многоконфессиональный_состав',
#  'сообщество',
#  'как',
#  'небольшой',
#  'пример',
#  'такой',
#  'подход',
#  'мочь_привести',
#  'пара',
#  'трофей',
#  'с',
#  'наш',
#  'форум',
#  'когда',
#  'зарегистрировать',
#  'пользователь',
#  'заходить',
#  'на',
#  'форум',
#  'из',
#  'результат',
#  'поиск',
#  'google',
#  'он',
#  'получать',
#  'трофей_lmgtfy',
#  'let',
#  'me',
#  'google',
#  'this',
#  'for',
#  'you',
#  'иметь',
#  'описание',
#  'you',
#  'know_the_forum',
#  'has',
#  'its',
#  'own',
#  'search_right',
#  'и',
#  'иконка',
#  'в',
#  'вид_блиц',
#  'из',
#  'мультик',
#  'пользователь',
#  'включить_для_себя_двухфакторный',
#  'авторизация',
#  'то',
#  'он',
#  'получить',
#  'трофей_better',
#  'safe_than_sorry',
#  'с',
#  'описание',
#  'enabled_authentication',
#  'because',
#  'why',
#  'not',
#  'и',
#  'иконка',
#  'защищать_профилактический',
#  'резиновый_изделие',
#  'подобный',
#  'подход',
#  'как',
#  'правило',
#  'вызывать_позитивный',
#  'реакция',
#  'сообщество',
#  'особенно',
#  'когда',
#  'такой',
#  'трофей',
#  'сделать',
#  'скрытый_и_вручаться',
#  'пользователь',
#  'неожиданно',
#  'для',
#  'они',
#  'о',
#  'результат',
#  'внедрение',
#  'этот',
#  'реализация_геймификация',
#  'с',
#  'точка_зрение',
#  'заявить',
#  'в',
#  'начало_статья',
#  'цель',
#  'говорить',
#  'пока_рано',
#  'но',
#  'тенденция_устойчивый',
#  'рост',
#  'активность',
#  'на',
#  'форум',
#  'заметный',
#  'сейчас',
#  'после',
#  'пара_месяц',
#  'с',
#  'время',
#  'запуск',
#  'система',
#  'сложно_оценить',
#  'доля_геймификация',
#  'в',
#  'это',
#  'но',
#  'по',
#  'мера_накопление',
#  'статистический_дать',
#  'она',
#  'влияние',
#  'можно',
#  'быть',
#  'попробовать',
#  'оценить',
#  'более',
#  'детально',
#  'если',
#  'у',
#  'вы',
#  'есть',
#  'опыт',
#  'по',
#  'внедрение',
#  'оценка',
#  'и',
#  'использование',
#  'система',
#  'геймификация_в_профильный',
#  'сообщество',
#  'делиться',
#  'пожалуйста_в_комментарий']

# %% [markdown]
# Для BigARTM требуется специальный формат данных. Их несколько, но мы возьмем vowpal wabbit.
# На каждой строчке файла находится одельный текст, записывается такст вот таким образом:
# ```doc_name |@class_id word_1:1 word_2:3```
#
# |@class_id - задает модальность, но когда она одна её можно не указывать.
#
# word_2:3 - слово и его частота (обратите внимание, что : - специальный символ и в словах его быть не может

# %% [markdown]
# ### 3) Сохраним файл

# %%
f = open('habr_texts_2.vw', 'w', encoding="utf-8")

for i, text in enumerate(ngrammed_habr_texts):
    c = Counter(text)
    doc = 'doc_'+ str(i) + ' '
    vw_text = ' '.join([x+':'+str(c[x]) for x in c])
    
    f.write(doc + vw_text  + '\n')
f.close()

# %% [markdown]
# Для оценки будем использовать такую функцию (из туториалов от создателей библиотеки)

# %%
def print_measures(model_artm):
    print('Sparsity Phi: {0:.3f} ARTM)'.format(
        model_artm.score_tracker['SparsityPhiScore'].last_value)
)
    print('Sparsity Theta: {0:.3f} (ARTM)'.format(
        model_artm.score_tracker['SparsityThetaScore'].last_value))

    print('Kernel contrast: {0:.3f} (ARTM)'.format(
        model_artm.score_tracker['TopicKernelScore'].last_average_contrast))

    print('Kernel purity: {0:.3f} (ARTM)'.format(
        model_artm.score_tracker['TopicKernelScore'].last_average_purity))

    print('Perplexity: {0:.3f} (ARTM)'.format(
        model_artm.score_tracker['PerplexityScore'].last_value)
)
    plt.plot(range(model_artm.num_phi_updates), model_artm.score_tracker['PerplexityScore'].value, 'r--', linewidth=2)
    plt.xlabel('Iterations count')
    plt.ylabel(' ARTM perp. (red)')
    plt.grid(True)
    plt.show()

# %% [markdown]
# BigARTM работает не с целым файлом, а с кусочками. Поэтому разбиваем наш .vw файл специальным классом в artm.

# %%
batch_vectorizer = artm.BatchVectorizer(data_path='habr_texts.vw',  # название файла
                                        data_format='vowpal_wabbit', # формат файла, у нас vw
                                        target_folder='batches', # название папки в которую положаться батчи
                                       batch_size=1000) # размер батча, подбирайте под свою память

# %% [markdown]
# Уже созданные батчи можно заново загружать

# %%
batch_vectorizer = artm.BatchVectorizer(data_path='batches', # название папки с батчами
                                        data_format='batches') # указываем формат - батчи

# %%
# инициализируем словарь, чтобы сделать модель
dictionary = artm.Dictionary()

# %% [markdown]
# Собираем словарь по батчам

# %%
dictionary.gather(data_path='batches')
dictionary.filter(class_id='@default_class',
                  min_df=30, max_df=200)

# %% [markdown]
# Его можно сохранить, чтобы не создавать снова или чтобы посмотреть и подредактировать.

# %%
dictionary.save_text('dict.txt')
# dictionary = artm.Dictionary()
# dictionary.load_text('dict.txt')

# %% [markdown]
# Создаем модель и сразу включаем два регуляризатора (Декореляции и Сглаживания)

# %% [markdown]
# ## Эта тетрадка использовалась для генерирования словаря. Остальное в BigARTM_continue_Nikishina

# %% [markdown]
# `artm.DecorrelatorPhiRegularizer` - регуляризатор декорреляции тем, делает темы менее похожими друг на друга (рекомендуется включать его сразу на всех темах с положительным значением tau и не менять его в процессе обучения)
#
# `artm.SmoothSparsePhiRegularizer` - регуляризатор сглаживания/разреженивания Phi (тем) - сглаживает или расреживает распределение слов в темах (отрицательный tau - разреживает, положительный - сглаживает), рекомендуется сразу включать сглаживание на всех темах и не менять его в процессе обучения;
#
# Количество тем нужно подбирать, но 200 часто работает хорошо. Снижение количества тем и уменьшения словаря ведут к уменьшению времени обучения модели (а увеличение, наоборот).

# %%
model_artm = artm.ARTM(topic_names=['topic_{}'.format(i) for i in range(30)],
                       
                       regularizers=[
                           artm.DecorrelatorPhiRegularizer(
                                            name='Decorr', tau=0.15, 
                                            class_ids=['@default_class'],
                                            topic_names=['topic_{}'.format(i) for i in range(0, 30)]),
                           
                           artm.SmoothSparsePhiRegularizer(
                                            name='SmoothPhi_1', 
                                            class_ids=['@default_class'],
                                            tau=0.25, 
                                            topic_names=['topic_{}'.format(i) for i in range(0, 30)])
                                    ]
                        )

# не забывайте менять количество топиков в регуляризаторах, они применяются только на тех темах, что заданы

# %%
# инициализурем модель словарем
model_artm.initialize(dictionary=dictionary, )

# %%
# добавляем метрики
model_artm.scores.add(artm.PerplexityScore(name='PerplexityScore',
                                                    dictionary=dictionary))
model_artm.scores.add(artm.SparsityPhiScore(name='SparsityPhiScore')) # разреженность слов в темах
model_artm.scores.add(artm.SparsityThetaScore(name='SparsityThetaScore')) # разреженность тем в доках
model_artm.scores.add(artm.TopicKernelScore(name='TopicKernelScore', probability_mass_threshold=0.1)) # когерентность по семантичесим ядрам
model_artm.scores.add(artm.TopTokensScore(class_id='@default_class', name='TopTokensScore_1', num_tokens=10)) # топ-n-слов для каждой темы

# %% [markdown]
# ### Тренируем модель

# %% [markdown]
# Пройдемся несколько раз по коллекции, чтобы модель немного сошлась (если доков сильно больше то может быть достаточно и 1 прохода). Для сильно больших коллекций есть fit_online, который обновляется в процессе прохода по коллекции, про него можно почитать в документации.

# %%
model_artm.num_document_passes = 50
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=10)

# %%
# посмотрим, что стало с моделью
# если график сильно падал на последних итерациях, то можно прогнать обучение ещё несколько раз 
# (не добавляя другие регуляризаторы)
print_measures(model_artm)
# Out:
# Sparsity Phi: 0.000 ARTM)
# Sparsity Theta: 0.433 (ARTM)
# Kernel contrast: 0.232 (ARTM)
# Kernel purity: 0.570 (ARTM)
# Perplexity: 471.417 (ARTM)

# %% [markdown]
# Добавим регуляризаторы разреженности тем и документов.
#
# Их рекомендуется добавлять после того, как модель уже как-то сошлась. После добавления их рекомендуется постепенно уменьшать, чтобы усиливать разреживание. Их можно применять не ко всем темам, чтобы в каких-то темах собрались все стоп-слова.
#
# Можно добавлять их вместе или по отдельности.

# %%
model_artm.regularizers.add(artm.SmoothSparsePhiRegularizer(name='SparsePhi', tau=-0.15, 
                                                            topic_names=['topic_{}'.format(i) for i in range(1, 20)],
                                                            ))
model_artm.regularizers.add(artm.SmoothSparseThetaRegularizer(name='SparseTheta', tau=-0.15, 
                                                              topic_names=['topic_{}'.format(i) for i in range(1, 20)]))

# %%
model_artm.fit_offline(batch_vectorizer=batch_vectorizer,num_collection_passes=1)

# %%
# будем постепенно увеличивать значения этих регуляризаторов
phi_tau = model_artm.regularizers['SparsePhi'].tau
theta_tau = model_artm.regularizers['SparseTheta'].tau

for i in range(10):
    model_artm.regularizers['SparsePhi'].tau = (phi_tau + (phi_tau*0.5))
    model_artm.regularizers['SparseTheta'].tau = (theta_tau + (theta_tau*0.1))
    
    model_artm.fit_offline(batch_vectorizer=batch_vectorizer,num_collection_passes=1)

# %%
# посмотрим на качество
print_measures(model_artm)
# Out:
# Sparsity Phi: 0.000 ARTM)
# Sparsity Theta: 0.690 (ARTM)
# Kernel contrast: 0.244 (ARTM)
# Kernel purity: 0.633 (ARTM)
# Perplexity: 462.989 (ARTM)

# %% [markdown]
# Перплексия должна снижаться. Если график выровнился и больше не меняется - модель сошлась. Обычно перплексия хорошей модели около 200-1000. На таком небольшом количестве данных возможно такого значения достичь не получится.

# %%
# посмотрим на темы
for topic_name in model_artm.topic_names[:50]:
    print(topic_name + ': ' + ", ".join(model_artm.score_tracker['TopTokensScore_1'].last_tokens[topic_name]))
# Out:
# topic_0: робот, скидка, накопитель, гаджет, аккумулятор, подарок, iphone, девайс, xiaomi, акция
# topic_1: amazon, лекция, выступление, go, кандидат, форум, рекламный, спикер, александр, андрей
# topic_2: дисплей, ноутбук, напряжение, чип, ток, гб, видеокарта, клавиатура, usb, аккумулятор
# topic_3: vr, персонаж, сцена, враг, движок, герой, жанр, спрайт, комната, game
# topic_4: пациент, клетка, болезнь, врач, организм, заболевание, ген, лечение, животное, бактерия
# topic_5: ibm, звонок, хостинг, резервный, заявка, цод, предприятие, 1с, oracle, crm
# topic_6: метка, маршрутизатор, шлюз, кабель, коммутатор, маршрут, маска, приёмник, битый, tcp
# topic_7: маркетинг, планирование, образование, школа, инвестор, студент, scrum, зарплата, профессия, инвестиция
# topic_8: print, char, байт, include, define, unsigned, file, input, f, output
# topic_9: div, swift, let, research, props, react, international, science, width, const
# topic_10: p, вакансия, параллельный, математика, указатель, математический, блокировка, linkedin, предметный, итерация
# topic_11: координата, вектор, матрица, float, текстура, сетка, пиксель, z, луч, h
# topic_12: полёт, спутник, луна, орбита, марс, космос, ракета, корабль, наса, val
# topic_13: сертификат, days, резервный, восстановление, main, токен, шифрование, копирование, func, подпись
# topic_14: кластер, end, хост, begin, git, sudo, docker, вм, nginx, нода
# topic_15: import, def, case, end, message, test, post, url, self, const
# topic_16: доход, блокчейн, платёж, банка, налог, китай, корпорация, государство, платёжный, суд
# topic_17: вселенная, звезда, квантовый, галактика, частица, тёмный, излучение, атом, лампа, фотон
# topic_18: php, иконка, ui, вкладка, локализация, studio, app, шрифт, unity, ide
# topic_19: j, std, bool, const, long, анализатор, byte, double, visual, r
# topic_20: анимация, css, react, js, angular, chrome, коллекция, фреймворк, асинхронный, firefox
# topic_21: private, static, object, result, const, item, override, e, let, list
# topic_22: ms, драйвер, регистр, стек, прерывание, cpu, pi, таймер, файловый, компилятор
# topic_23: печать, принтер, мм, станок, option, 3d, лазер, бумага, металл, изделие
# topic_24: бот, слушать, наушник, звуковой, чат, telegram, колонка, бренд, мессенджер, телевизор
# topic_25: солнечный, двигатель, планета, километр, астероид, здание, прибор, атмосфера, испытание, ветер
# topic_26: тз, твой, велосипед, карточка, кейс, спрашивать, честно, тестировщик, доска, админ
# topic_27: уязвимость, домен, злоумышленник, вредоносный, почтовый, блокировка, email, транзакция, хакер, взлом
# topic_28: ия, нейронный, нейросеть, интеллект, нейрон, распознавание, обучать, сознание, предсказание, классификация
# topic_29: select, add, table, array, go, default, echo, php, create, varchar
